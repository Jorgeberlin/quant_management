# %%
import pandas as pd
import numpy as np

prices = pd.Series(
    [100, 105, 102, 108, 101], 
    index=pd.date_range("2026-01-01", periods=5)
)

print(prices)
# Out:
# 2026-01-01    100
# 2026-01-02    105
# 2026-01-03    102
# 2026-01-04    108
# 2026-01-05    101
# Freq: D, dtype: int64

# %%
def cagr(prices: pd.Series | pd.DataFrame,method: str = "simple") -> pd.Series | pd.DataFrame:
    print((prices[-1] / prices[0])**(1/(len(prices)/252))-1)
    return (prices[-1] / prices[0])**(1/(len(prices)/252))-1

# %%
cagr(prices)
# Out:
# 0.6511907181265544
# C:\Users\jorpe\AppData\Local\Temp\ipykernel_14668\1911641612.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print((prices[-1] / prices[0])**(1/(len(prices)/252))-1)
# C:\Users\jorpe\AppData\Local\Temp\ipykernel_14668\1911641612.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return (prices[-1] / prices[0])**(1/(len(prices)/252))-1
# np.float64(0.6511907181265544)

# %%
prices = pd.Series([100, 110, 99,12,243])
prices[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\jorpe\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 2
#       1 prices = pd.Series([100, 110, 99,12,243])
# ----> 2 prices[-1]
#
# File c:\Users\jorpe\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
# ...
